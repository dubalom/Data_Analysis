# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def perform_eda(file_path):
    # Load the dataset
    df = pd.read_csv(file_path)
    
    # Display descriptive statistics
    print("Descriptive Statistics:")
    print(df.describe())
    
    # Plot GDP over time
    plt.figure(figsize=(10, 6))
    plt.plot(df['Year'], df['GDP'], marker='o')
    plt.title("GDP Over Time")
    plt.xlabel("Year")
    plt.ylabel("GDP (Billion USD)")
    plt.grid(True)
    plt.savefig("../plots/gdp_over_time.png")
    plt.show()
    
    # Generate a correlation heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
    plt.title("Correlation Heatmap")
    plt.savefig("../plots/correlation_heatmap.png")
    plt.show()

if __name__ == "__main__":
    file_path = "../data/russian_economic_data.csv"
    perform_eda(file_path)
# Out:
# Descriptive Statistics:
#               Year          GDP  Inflation  Unemployment     Exports
# count    31.000000    31.000000  31.000000     31.000000   31.000000
# mean   2005.000000  1012.258065   4.703226      5.877419  222.903226
# std       9.092121   431.875828   1.962903      1.236045  104.904514
# min    1990.000000   300.000000   2.700000      4.600000   50.000000
# 25%    1997.500000   656.000000   3.300000      4.950000  136.000000
# 50%    2005.000000  1012.000000   4.000000      5.200000  223.000000
# 75%    2012.500000  1368.500000   5.500000      6.900000  309.500000
# max    2020.000000  1725.000000  10.500000      8.500000  396.000000
